# %% [markdown]
# # <center> Tableau Dashboard Dataset Selection
#
# <center> Anqi Zhu

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Google Play Dataset

# %% [markdown]
# https://www.kaggle.com/datasets/tapive/google-play-apps-and-games
#
# Enough dimansions and measures. While someone has aleady output a [report](https://tapive.com/blog/report-analysis-apps-on-google-play).

# %%
df = pd.read_csv("google-play-dataset-by-tapivedotcom.csv")
df.head()
# Out:
#    Unnamed: 0                                              appId  \
# 0           0  com.cyou.cma.clauncher.theme.v542279ccb70366ba...
# 1           1  com.cyou.cma.clauncher.theme.v546307d9199ddff3...
# 2           2                            com.kids.paint.free.app
# 3           3      com.touchpal.touchpal_skins_tropical_paradise
# 4           4                                   com.musmon.Prado
#
#                       developer          developerId  \
# 0           Best theme workshop  7398289236941441420
# 1  Best Android Themes Workshop  5762674363677973291
# 2                   NAVEENKUMAR          NAVEENKUMAR
# 3                   360 Fractal          360+Fractal
# 4                    MUSMon.com           MUSMon.com
#
#                        developerWebsite  free         genre         genreId  \
# 0            http://www.c-launcher.com/     1  Art & Design  ART_AND_DESIGN
# 1            http://www.c-launcher.com/     1  Art & Design  ART_AND_DESIGN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3451063 entries, 0 to 3451062
# Data columns (total 36 columns):
#  #   Column                Dtype
# ---  ------                -----
#  0   Unnamed: 0            int64
#  1   appId                 object
#  2   developer             object
#  3   developerId           object
#  4   developerWebsite      object
#  5   free                  int64
#  6   genre                 object
#  7   genreId               object
#  8   inAppProductPrice     object
#  9   minInstalls           int64
#  10  offersIAP             int64
#  11  originalPrice         object
#  12  price                 float64
#  13  ratings               int64
#  14  len screenshots       int64
#  15  adSupported           int64
#  16  containsAds           int64
#  17  reviews               int64
#  18  releasedDayYear       object
#  19  sale                  int64
#  20  score                 float64
#  21  summary               object
# ...

# %% [markdown]
# the dataset is too large, so I decided to extracted the leatest ones.

# %%
df_latest = df[df["dateUpdated"]>"2022-11-01 00:00:00"]

# %%
df_latest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2043 entries, 902 to 191485
# Data columns (total 36 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            2043 non-null   int64
#  1   appId                 2043 non-null   object
#  2   developer             2043 non-null   object
#  3   developerId           2043 non-null   object
#  4   developerWebsite      2043 non-null   object
#  5   free                  2043 non-null   int64
#  6   genre                 2043 non-null   object
#  7   genreId               2043 non-null   object
#  8   inAppProductPrice     2043 non-null   object
#  9   minInstalls           2043 non-null   int64
#  10  offersIAP             2043 non-null   int64
#  11  originalPrice         2043 non-null   object
#  12  price                 2043 non-null   float64
#  13  ratings               2043 non-null   int64
#  14  len screenshots       2043 non-null   int64
# ...

# %% [markdown]
# # Airbnb Dataset

# %% [markdown]
# https://www.kaggle.com/datasets/tamle507/airbnb-listings-usa
#
# Similar to google play dataset. Good data except someone has built a [tableau story](https://public.tableau.com/app/profile/tamle507/viz/AirbnbUSAListingsStory/USA). Maybe we can improve it!

# %%
df_airbnb = pd.read_csv("airbnb_listings_usa.csv", low_memory=False)
df_airbnb.head()
# Out:
#    Unnamed: 0      id                                               name  \
# 0           0  183319                  Panoramic Ocean View Venice Beach
# 1           1     109  Amazing bright elegant condo park front *UPGRA...
# 2           2   51307  Spanish Bungalow Guest House LA CA. 30 plus ni...
# 3           3  184314                    Boho Chic Flat..Steps to Beach!
# 4           4   51498  Guest House With Its Own Entrance/Exit and Hot...
#
#    host_id  host_name  neighbourhood_group    neighbourhood  latitude  \
# 0   867995  Barbara X  City of Los Angeles           Venice  33.99211
# 1      521      Paolo         Other Cities      Culver City  33.98301
# 2   235568      David  City of Los Angeles  Atwater Village  34.12206
# 3   884031     Ashley  City of Los Angeles           Venice  33.97487
# 4   236758        Bay  City of Los Angeles        Mar Vista  34.00389
#
#    longitude        room_type  ...  minimum_nights  number_of_reviews  \
# ...

# %%
df_airbnb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 325858 entries, 0 to 325857
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   Unnamed: 0                      325858 non-null  int64
#  1   id                              325858 non-null  int64
#  2   name                            325839 non-null  object
#  3   host_id                         325858 non-null  int64
#  4   host_name                       324714 non-null  object
#  5   neighbourhood_group             155047 non-null  object
#  6   neighbourhood                   325146 non-null  object
#  7   latitude                        325858 non-null  float64
#  8   longitude                       325858 non-null  float64
#  9   room_type                       325858 non-null  object
#  10  price                           325858 non-null  int64
#  11  minimum_nights                  325858 non-null  int64
# ...

# %%
df_airbnb_latest = df_airbnb[df_airbnb["last_review"]>"2022-09-15 00:00:00"]

# %%
df_airbnb_latest.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6778 entries, 91782 to 325822
# Data columns (total 21 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      6778 non-null   int64
#  1   id                              6778 non-null   int64
#  2   name                            6778 non-null   object
#  3   host_id                         6778 non-null   int64
#  4   host_name                       6777 non-null   object
#  5   neighbourhood_group             1441 non-null   object
#  6   neighbourhood                   6778 non-null   object
#  7   latitude                        6778 non-null   float64
#  8   longitude                       6778 non-null   float64
#  9   room_type                       6778 non-null   object
#  10  price                           6778 non-null   int64
#  11  minimum_nights                  6778 non-null   int64
# ...

# %% [markdown]
# # App Store Dataset

# %% [markdown]
# https://www.kaggle.com/datasets/ramamet4/app-store-apple-data-set-10k-apps
#
# Limited dimensions. Not as good as the first two. A non-English simple [PowerBI dashboard](https://app.powerbi.com/view?r=eyJrIjoiMjFhZjg3ODgtYjFmZC00MzU5LTliYjktOTA3NTVmYWQwZjhmIiwidCI6IjdlNjVmZWY2LWFkYjQtNGZmMC05YWQ3LTViNzM0ZGI4YmU5NiJ9).

# %%
df_app = pd.read_csv("AppleStore.csv")
df_app.head()
# Out:
#    Unnamed: 0         id                                         track_name  \
# 0           1  281656475                                    PAC-MAN Premium
# 1           2  281796108                          Evernote - stay organized
# 2           3  281940292    WeatherBug - Local Weather, Radar, Maps, Alerts
# 3           4  282614216  eBay: Best App to Buy, Sell, Save! Online Shop...
# 4           5  282935706                                              Bible
#
#    size_bytes currency  price  rating_count_tot  rating_count_ver  \
# 0   100788224      USD   3.99             21292                26
# 1   158578688      USD   0.00            161065                26
# 2   100524032      USD   0.00            188583              2822
# 3   128512000      USD   0.00            262241               649
# 4    92774400      USD   0.00            985920              5320
#
#    user_rating  user_rating_ver     ver cont_rating   prime_genre  \
# ...

# %%
df_app.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7197 entries, 0 to 7196
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        7197 non-null   int64
#  1   id                7197 non-null   int64
#  2   track_name        7197 non-null   object
#  3   size_bytes        7197 non-null   int64
#  4   currency          7197 non-null   object
#  5   price             7197 non-null   float64
#  6   rating_count_tot  7197 non-null   int64
#  7   rating_count_ver  7197 non-null   int64
#  8   user_rating       7197 non-null   float64
#  9   user_rating_ver   7197 non-null   float64
#  10  ver               7197 non-null   object
#  11  cont_rating       7197 non-null   object
#  12  prime_genre       7197 non-null   object
#  13  sup_devices.num   7197 non-null   int64
#  14  ipadSc_urls.num   7197 non-null   int64
#  15  lang.num          7197 non-null   int64
# ...

# %% [markdown]
# # IMDB Dataset

# %% [markdown]
# https://www.kaggle.com/datasets/mustafacicek/imdb-top-250-lists-1996-2020

# %%
df_imdb = pd.read_csv("imdbTop250.csv")
df_imdb.head()
# Out:
#    Ranking  IMDByear           IMDBlink                               Title  \
# 0        1      1996  /title/tt0076759/  Star Wars: Episode IV - A New Hope
# 1        2      1996  /title/tt0111161/            The Shawshank Redemption
# 2        3      1996  /title/tt0117951/                       Trainspotting
# 3        4      1996  /title/tt0114814/                  The Usual Suspects
# 4        5      1996  /title/tt0108598/                  The Wrong Trousers
#
#    Date  RunTime                       Genre  Rating  Score    Votes   Gross  \
# 0  1977      121  Action, Adventure, Fantasy     8.6   90.0  1299781  322.74
# 1  1994      142                       Drama     9.3   80.0  2529673   28.34
# 2  1996       93                       Drama     8.1   83.0   665213   16.50
# 3  1995      106       Crime, Drama, Mystery     8.5   77.0  1045626   23.34
# 4  1993       30    Animation, Short, Comedy     8.3    NaN    53316     NaN
#
# ...

# %%
df_imdb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6500 entries, 0 to 6499
# Data columns (total 16 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Ranking   6500 non-null   int64
#  1   IMDByear  6500 non-null   int64
#  2   IMDBlink  6500 non-null   object
#  3   Title     6500 non-null   object
#  4   Date      6500 non-null   int64
#  5   RunTime   6500 non-null   int64
#  6   Genre     6500 non-null   object
#  7   Rating    6500 non-null   float64
#  8   Score     5674 non-null   float64
#  9   Votes     6500 non-null   int64
#  10  Gross     5691 non-null   float64
#  11  Director  6500 non-null   object
#  12  Cast1     6500 non-null   object
#  13  Cast2     6500 non-null   object
#  14  Cast3     6492 non-null   object
#  15  Cast4     6492 non-null   object
# dtypes: float64(3), int64(5), object(8)
# memory usage: 812.6+ KB
